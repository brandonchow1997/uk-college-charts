# %%
import pymongo
import pandas as pd
client = pymongo.MongoClient('localhost',27017)
db  = client['zhihu_college']
table = db['comments_Bath']
data_Bath = pd.DataFrame(list(table.find()))
del data_Bath['_id']
Bath = data_Bath.mean()[0].round(3)
Bath_rank = 158

# %%
db  = client['zhihu_college']
table = db['comments_Durham']
data_Durham = pd.DataFrame(list(table.find()))
del data_Durham['_id']
Durham = data_Durham.mean()[0].round(3)
Durham_rank = 74

# %%
db  = client['zhihu_college']
table = db['comments_Edinburgh']
data_Edinburgh = pd.DataFrame(list(table.find()))
del data_Edinburgh['_id']
Edinburgh = data_Edinburgh.mean()[0].round(3)
Edinburgh_rank = 18

# %%
db  = client['zhihu_college']
table = db['comments_Lancaster']
data_Lancaster = pd.DataFrame(list(table.find()))
del data_Lancaster['_id']
Lancaster = data_Lancaster.mean()[0].round(3)
Lancaster_rank = 131

# %%
db  = client['zhihu_college']
table = db['comments_Leeds']
data_Leeds = pd.DataFrame(list(table.find()))
del data_Leeds['_id']
Leeds = data_Leeds.mean()[0].round(3)
Leeds_rank = 93

# %%
db  = client['zhihu_college']
table = db['comments_Leicester']
data_Leicester = pd.DataFrame(list(table.find()))
del data_Leicester['_id']
Leicester = data_Leicester.mean()[0].round(3)
Leicester_rank = 165

# %%
db  = client['zhihu_college']
table = db['comments_Loughborough']
data_Loughborough = pd.DataFrame(list(table.find()))
del data_Loughborough['_id']
Loughborough = data_Loughborough.mean()[0].round(3)
Loughborough_rank = 218

# %%
db  = client['zhihu_college']
table = db['comments_Manchester']
data_Manchester = pd.DataFrame(list(table.find()))
del data_Manchester['_id']
Manchester = data_Manchester.mean()[0].round(3)
Manchester_rank = 29

# %%
db  = client['zhihu_college']
table = db['comments_Newcastle']
data_Newcastle = pd.DataFrame(list(table.find()))
del data_Newcastle['_id']
Newcastle = data_Newcastle.mean()[0].round(3)
Newcastle_rank = 161

# %%
db  = client['zhihu_college']
table = db['comments_Nottingham']
data_Nottingham = pd.DataFrame(list(table.find()))
del data_Nottingham['_id']
Nottingham = data_Nottingham.mean()[0].round(3)
Nottingham_rank = 84

# %%
db  = client['zhihu_college']
table = db['comments_Warwick']
data_Warwick = pd.DataFrame(list(table.find()))
del data_Warwick['_id']
Warwick = data_Warwick.mean()[0].round(3)
Warwick_rank = 54

# %%
x = [Bath, Durham, Edinburgh, Lancaster, Leeds, Leicester,Loughborough,Manchester,Newcastle,Nottingham,Warwick]
x.sort()

# %%
from pyecharts import online

online() # needed for online viewing

# %%
from pyecharts import Bar
from pyecharts import Line

attr = ["Bath", "Durham", "Edinburgh", "Lancaster", "Leeds", "Leicester","Loughborough","Manchester","Newcastle","Nottingham","Warwick"]
x
bar = Bar(width=800, height=500)

bar.add("评论极性", attr, x,mark_line=["average"],mark_point=["min", "max"],is_label_show=True,is_more_utils=True
        ,xaxis_interval=0, xaxis_rotate=30, yaxis_min=0.5,yaxis_rotate=30)

# %%
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="8dbb9118c5c144e6accb0b9d38ee7eb3" style="width:800px;height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_8dbb9118c5c144e6accb0b9d38ee7eb3 = echarts.init(document.getElementById('8dbb9118c5c144e6accb0b9d38ee7eb3'), 'light', {renderer: 'canvas'});
#
# var option_8dbb9118c5c144e6accb0b9d38ee7eb3 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
# ...

# %%
from pyecharts import Bar3D

bar3d = Bar3D("", width=1200, height=600)
x_axis = ["Bath", "Durham", "Edinburgh", "Lancaster", "Leeds", "Leicester","Loughborough","Manchester","Newcastle","Nottingham","Warwick"]
y_aixs = ["top50", "top100", "top150", "top200", "top250"]
data = [[0, 2, Bath],[1,1,Durham],[2,0,Edinburgh],[3,2,Lancaster],[4,1,Leeds],[5,3,Leicester],[6,4,Loughborough],[7,0,Manchester],[8,3,Newcastle]
        ,[9,1,Nottingham],[10,0,Warwick]]
range_color = ['#313695', '#4575b4', '#74add1', '#abd9e9', '#e0f3f8', '#ffffbf',
               '#fee090', '#fdae61', '#f46d43', '#d73027', '#a50026']
bar3d.add("", x_axis,y_aixs, [[d[0], d[1], d[2]] for d in data], is_visualmap=True, visual_range=[0.54, 0.65],
          visual_range_color=range_color, grid3d_width=200, grid3d_depth=120,
         zaxis3d_min=0.53,xaxis3d_interval=0)

bar3d
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts.min', 'echartsgl': 'https://pyecharts.github.io/jupyter-echarts/echarts/echarts-gl.min'
#         }
#     });
# </script>
#     <div id="c66d27b1b03c4b49aecc1bb7e6881257" style="width:1200px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'echartsgl'], function(echarts) {
#
# var myChart_c66d27b1b03c4b49aecc1bb7e6881257 = echarts.init(document.getElementById('c66d27b1b03c4b49aecc1bb7e6881257'), 'light', {renderer: 'canvas'});
#
# var option_c66d27b1b03c4b49aecc1bb7e6881257 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
# ...
